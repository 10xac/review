# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
cpath = os.path.abspath('../')
print(cpath)
if cpath not in sys.path:
    sys.path.insert(0, cpath)
os.environ["STRAPI_STAGE"] = "prod"
# Out:
# /Users/mahlettaye/review

# %%
from review_scripts.insert_interview import InsertInterview
# Out:
# /Users/mahlettaye/review
# config.py:get_openapi_token:26: get_auth(ssmkey=OPENAI_API_KEY, envvar=openai_apikey, fconfig=.env/openai_apikey.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# using STRAPI_STAGE=prod
# /Users/mahlettaye/review

# %%
sid_ = "1DAsXoIWy0TQB1dCJ6dt9jC3RQazR9QDt7ybWlv3BDL4"
sheet_name = "EA - Interview - ALL"
batch = 9
status = "Accepted"
review_category_id = 17
run_stage="prod"
ii = InsertInterview( run_stage=run_stage, sid_interview_admited = sid_,
                        sheet_name = sheet_name,
                        batch = batch,
                        status = status,
                        review_category_id = review_category_id

                        )
# Out:
# Strapimethods run_stage: prod
# strapi_methods.py:__init__:33: get_auth(ssmkey=TENX_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/cms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# StrapiGraphql run_stage: prod
# strapi_graphql.py:__init__:35: get_auth(ssmkey=TENX_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/cms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..

# %%
ii.sm.apiroot
# Out:
# 'https://cms.10academy.org'

# %%
ii.sg.apiroot
# Out:
# 'https://cms.10academy.org/graphql'

# %%
trainee_df = ii.get_interview_admitted_trainees()
# Out:
# gdrive.py:__init__:99: get_auth(ssmkey=gspread/config, envvar=GSPREAD_CONFIG, fconfig=~/.env/gclass_credentials.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# Getting gspread/config from aws secret manager as it can not be found in tenx/env/vars ..
# writing /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/gclass_credentials.json file ..
# ****** using service account: ~/.env/gclass_credentials.json
# service account is being used without delegation..
# ------------EA - Interview - ALL df.shape=(13, 7)----

# %%
trainee_df
# Out:
#                        Name                       Email  Gender Nationality  \
# 1           Alazar Getachew  alazargetachew70@gmail.com    Male    Ethiopia
# 2             Mekbib Ayalew        mekbibtare@gmail.com    Male    Ethiopia
# 3               Mama Kebede    mamamohammed31@gmail.com    Male    Ethiopia
# 4             Ararso Alisho      areealisho12@gmail.com    Male    Ethiopia
# 5   Carmel Zerihun Desalegn    carmel.zerihun@gmail.com    Male    Ethiopia
# 6         Elizabeth Nanjala       nanjalaliz7@gmail.com  Female       Kenya
# 7            Sumeya Sirmola   sumeyasirmulach@gmail.com  Female    Ethiopia
# 8       Abel Adissu Tsegaye  avelodollasign84@gmail.com    Male    Ethiopia
# 9             Godswill Otto  godswillchidubam@gmail.com    Male     Nigeria
# 10           ABDULAZIZ REDI   abdulazizredi90@gmail.com    Male    Ethiopia
# 11               Stacy Mbau      gathigiambau@gmail.com  Female       Kenya
# ...

# %%
accepted_df = ii.get_accepted_trainee()

# %%
accepted_df
# Out:
#                 attributes.email    id  \
# 0       dagmawemenelek@gmail.com  2272
# 1             mbedru18@yahoo.com  2266
# 2          faromika.me@gmail.com  2273
# 3     alazargetachew70@gmail.com  2287
# 4      getahunmulugete@gmail.com  2277
# 5         sitotaerkalo@gmail.com  2265
# 6        kalbmehari603@gmail.com  2283
# 7     avelodollasign84@gmail.com  2279
# 8           pikejiofor@gmail.com  2268
# 9       mamamohammed31@gmail.com  2270
# 10    pharisahmedyahya@gmail.com  2269
# 11       eyobgayalew74@gmail.com  2262
# 12     sumeyasirmulach@gmail.com  2260
# 13       chalielijalem@gmail.com  1994
# 14    zelalemabebaw187@gmail.com  2275
# 15      carmel.zerihun@gmail.com  2261
# 16         nanjalaliz7@gmail.com  2276
# 17         aklileyilma@gmail.com  2267
# 18            nebogech@gmail.com  2281
# 19     abdulazizredi90@gmail.com  2285
# 20           abdie6722@gmail.com  2274
# 21        areealisho12@gmail.com  2282
# 22          mekbibtare@gmail.com  2209
# ...

# %%
xx = ii.get_reviewers()
len (xx)
# Out:
# 14

# %% [markdown]
# ### Insert Interview

# %%
final_df =  ii.insert_interview()
# Out:
# gdrive.py:__init__:99: get_auth(ssmkey=gspread/config, envvar=GSPREAD_CONFIG, fconfig=~/.env/gclass_credentials.json)
# reading auth from file: /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/gclass_credentials.json ..
# ****** using service account: ~/.env/gclass_credentials.json
# service account is being used without delegation..
# ------------EA - Interview - ALL df.shape=(13, 7)----
# https://cms.10academy.org/api/reviews
# {'data': {'id': 6247, 'attributes': {'prefilled_response': None, 'createdAt': '2024-09-05T08:43:33.221Z', 'updatedAt': '2024-09-05T08:43:33.221Z', 'publishedAt': '2024-09-05T08:43:33.216Z'}}, 'meta': {}}
# https://cms.10academy.org/api/reviews
# {'data': {'id': 6248, 'attributes': {'prefilled_response': None, 'createdAt': '2024-09-05T08:43:34.258Z', 'updatedAt': '2024-09-05T08:43:34.258Z', 'publishedAt': '2024-09-05T08:43:34.251Z'}}, 'meta': {}}
# https://cms.10academy.org/api/reviews
# ...

# %%
final_df
# Out:
#                        Name                       email  Gender Nationality  \
# 0           Alazar Getachew  alazargetachew70@gmail.com    Male    Ethiopia
# 1             Mekbib Ayalew        mekbibtare@gmail.com    Male    Ethiopia
# 2               Mama Kebede    mamamohammed31@gmail.com    Male    Ethiopia
# 3             Ararso Alisho      areealisho12@gmail.com    Male    Ethiopia
# 4   Carmel Zerihun Desalegn    carmel.zerihun@gmail.com    Male    Ethiopia
# 5         Elizabeth Nanjala       nanjalaliz7@gmail.com  Female       Kenya
# 6            Sumeya Sirmola   sumeyasirmulach@gmail.com  Female    Ethiopia
# 7       Abel Adissu Tsegaye  avelodollasign84@gmail.com    Male    Ethiopia
# 8             Godswill Otto  godswillchidubam@gmail.com    Male     Nigeria
# 9            ABDULAZIZ REDI   abdulazizredi90@gmail.com    Male    Ethiopia
# 10               Stacy Mbau      gathigiambau@gmail.com  Female       Kenya
# ...
