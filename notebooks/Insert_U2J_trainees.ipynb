# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys
cpath = os.path.abspath('../')
print(cpath)
if cpath not in sys.path:
    sys.path.insert(0, cpath)
os.environ["STRAPI_STAGE"] = "u2jcms" #"devu2j"#"u2jcms"
# Out:
# /Users/mahlettaye/review

# %% [markdown]
# ### For new trainees  batch like u2j
# - Create user and allUesr for Trainee
# - Create profile Information
# - Create group
# - create Trainee

# %%
from review_scripts.trainee_information_processor import TraineeInformationProcesssor
from review_scripts.strapi_methods import StrapiMethods 
from review_scripts.strapi_graphql import StrapiGraphql
from review_scripts.communication_manager import CommunicationManager
### Load params 
from run_configs import u2j_batch2_trainee_config
# Out:
# /Users/mahlettaye/review
# /Users/mahlettaye/review
# config.py:get_openapi_token:26: get_auth(ssmkey=OPENAI_API_KEY, envvar=openai_apikey, fconfig=.env/openai_apikey.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# using STRAPI_STAGE=u2jcms
# /Users/mahlettaye/review

# %%
sg = StrapiGraphql(run_stage=u2j_batch2_trainee_config.run_stage)
sm = StrapiMethods(run_stage=u2j_batch2_trainee_config.run_stage)
cm = CommunicationManager()
tip = TraineeInformationProcesssor()
# Out:
# StrapiGraphql run_stage: u2jcms
# strapi_graphql.py:__init__:35: get_auth(ssmkey=U2J_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/u2jcms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# Strapimethods run_stage: u2jcms
# strapi_methods.py:__init__:33: get_auth(ssmkey=U2J_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/u2jcms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# StrapiGraphql run_stage: u2jcms
# strapi_graphql.py:__init__:35: get_auth(ssmkey=U2J_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/u2jcms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..
# Strapimethods run_stage: u2jcms
# strapi_methods.py:__init__:33: get_auth(ssmkey=U2J_PROD_STRAPI_TOKEN, envvar=STRAPI_TOKEN, fconfig=/var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/u2jcms.json)
# Getting tenx/env/vars from existing file /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/tenx_env_vars.json..

# %% [markdown]
# ### create user, all user for trainees

# %%
ddf = tip.prepare_applicants()
# Out:
# gdrive.py:__init__:99: get_auth(ssmkey=gspread/config, envvar=GSPREAD_CONFIG, fconfig=~/.env/gclass_credentials.json)
# reading auth from file: /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/gclass_credentials.json ..
# ****** using service account: ~/.env/gclass_credentials.json
# service account is being used without delegation..
# ------------u2j-batch2 - Week 5 df.shape=(53, 4)----
# /Users/mahlettaye/miniconda3/envs/pjmatch/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
# 38       medhanitworkneh@gmail.com     Medhanit Teshome Wodajo  Ethiopia
# 39             mareye132@gmail.com       Mareye Zeleke Mekonen  Ethiopia
# 40             aponan122@gmail.com                Nafol Abdisa  Ethiopia
# 41         ruthtsegaye70@gmail.com                Ruth Tsegaye  Ethiopia
# 42             zemickeyx@gmail.com             Zemichael Moges  Ethiopia
# 43        samuelabera523@gmail.com               Samuel Aberra  Ethiopia
# 44               eshet22@gmail.com            Abenezer Tadesse  Ethiopia
# 45         ahailemelekot@gmail.com         Hailemelekot Amsalu  Ethiopia
# 46             tlugodiva@gmail.com            T Tunde A Fasasi   Liberia
# 47          eyasuachiso2@gmail.com                Eyasu Achiso  Ethiopia
# 48         milkiitolasa2@gmail.com          Hailemariam Adugna  Ethiopia
# 49      melatwegebriel12@gmail.com          Melat Weldegebriel  Ethiopia
# 50       ebenezerteshe05@gmail.com            Abenezer Teshome  Ethiopia
# 51           sunny.tsega@gmail.com                Tsega Abinet  Ethiopia
# 52        oyelola_saheed@yahoo.com              Saheed Oyelola   Nigeria
# 53              oc.abuka@gmail.com                  Owen Abuka   Nigeria
#
#                gender     role  Batch
# 1                Male  trainee      2
# 2              Female  trainee      2
# 3              Female  trainee      2
# 4              Female  trainee      2
# 5              Female  trainee      2
# 6                Male  trainee      2
# 7                Male  trainee      2
# 8                Male  trainee      2
# 9              Female  trainee      2
# 10               Male  trainee      2
# 11               Male  trainee      2
# 12               Male  trainee      2
# 13               Male  trainee      2
# 14               Male  trainee      2
# 15               Male  trainee      2
# 16             Female  trainee      2
# 17               Male  trainee      2
# 18               Male  trainee      2
# 19             Female  trainee      2
# 20               Male  trainee      2
# 21               Male  trainee      2
# 22               Male  trainee      2
# 23             Female  trainee      2
# 24               Male  trainee      2
# 25               Male  trainee      2
# 26             Female  trainee      2
# 27               Male  trainee      2
# 28               Male  trainee      2
# 29               Male  trainee      2
# 30               Male  trainee      2
# 31             Female  trainee      2
# 32               Male  trainee      2
# 33             Female  trainee      2
# 34               Male  trainee      2
# 35               Male  trainee      2
# 36               Male  trainee      2
# 37               Male  trainee      2
# 38             Female  trainee      2
# 39               Male  trainee      2
# 40               Male  trainee      2
# 41             Female  trainee      2
# 42               Male  trainee      2
# 43               Male  trainee      2
# 44               Male  trainee      2
# 45               Male  trainee      2
# 46               Male  trainee      2
# 47               Male  trainee      2
# 48               Male  trainee      2
# 49             Female  trainee      2
# 50               Male  trainee      2
# 51               Male  trainee      2
# 52  Prefer not to say  trainee      2
# 53               Male  trainee      2

# %%
tip.sg.apiroot
# https://dev-u2jcms.10academy.org/graphql
# Out:
# 'https://u2jcms.10academy.org/graphql'

# %%
### to create user and all user 
tip.process_user_and_alluser_insertion()
# Out:
# gdrive.py:__init__:99: get_auth(ssmkey=gspread/config, envvar=GSPREAD_CONFIG, fconfig=~/.env/gclass_credentials.json)
# reading auth from file: /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/gclass_credentials.json ..
# ****** using service account: ~/.env/gclass_credentials.json
# service account is being used without delegation..
# ------------u2j-batch2 - Week 5 df.shape=(53, 4)----
# inserting user..... {'name': 'Nzamwitakuze Fabrice', 'email': 'fabricenzamwitakuze1@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Nzamwitakuze Fabrice', 'email': 'fabricenzamwitakuze1@gmail.com'}
# /Users/mahlettaye/miniconda3/envs/pjmatch/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# result json {'data': {'register': {'user': {'id': '1204', 'username': 'Nzamwitakuze Fabrice', 'email': 'fabricenzamwitakuze1@gmail.com'}}}}
# inserting user..... {'name': 'Niwemutoni Gratia Laetitia', 'email': 'lagrande997@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Niwemutoni Gratia Laetitia', 'email': 'lagrande997@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1205', 'username': 'Niwemutoni Gratia Laetitia', 'email': 'lagrande997@gmail.com'}}}}
# inserting user..... {'name': 'Burtukan Edao', 'email': 'edaoburtukan40@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Burtukan Edao', 'email': 'edaoburtukan40@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1206', 'username': 'Burtukan Edao', 'email': 'edaoburtukan40@gmail.com'}}}}
# inserting user..... {'name': 'Etornam Sika', 'email': 'etornam339@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Etornam Sika', 'email': 'etornam339@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1207', 'username': 'Etornam Sika', 'email': 'etornam339@gmail.com'}}}}
# inserting user..... {'name': 'Stacy Wairegi', 'email': 'stacywairegi@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Stacy Wairegi', 'email': 'stacywairegi@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1208', 'username': 'Stacy Wairegi', 'email': 'stacywairegi@gmail.com'}}}}
# inserting user..... {'name': 'Getachew Alemayehu', 'email': 'gechalex05@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Getachew Alemayehu', 'email': 'gechalex05@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1209', 'username': 'Getachew Alemayehu', 'email': 'gechalex05@gmail.com'}}}}
# inserting user..... {'name': 'Natoli Adugna', 'email': 'natoliadugnatafa@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Natoli Adugna', 'email': 'natoliadugnatafa@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1210', 'username': 'Natoli Adugna', 'email': 'natoliadugnatafa@gmail.com'}}}}
# inserting user..... {'name': 'Abel Awelachew', 'email': 'abelaw84@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Abel Awelachew', 'email': 'abelaw84@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1211', 'username': 'Abel Awelachew', 'email': 'abelaw84@gmail.com'}}}}
# inserting user..... {'name': 'Dibora Abraham', 'email': 'diboraabraham2@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Dibora Abraham', 'email': 'diboraabraham2@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1212', 'username': 'Dibora Abraham', 'email': 'diboraabraham2@gmail.com'}}}}
# inserting user..... {'name': 'Dagim Micheal', 'email': 'dagimmic97@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Dagim Micheal', 'email': 'dagimmic97@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1213', 'username': 'Dagim Micheal', 'email': 'dagimmic97@gmail.com'}}}}
# inserting user..... {'name': 'Didier Haragirimana', 'email': 'didierharagirimana@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Didier Haragirimana', 'email': 'didierharagirimana@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1214', 'username': 'Didier Haragirimana', 'email': 'didierharagirimana@gmail.com'}}}}
# inserting user..... {'name': 'John Kennedy Onyemaechi', 'email': 'john.k.onyemaechi@outlook.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'John Kennedy Onyemaechi', 'email': 'john.k.onyemaechi@outlook.com'}
# result json {'data': {'register': {'user': {'id': '1215', 'username': 'John Kennedy Onyemaechi', 'email': 'john.k.onyemaechi@outlook.com'}}}}
# inserting user..... {'name': 'Mickiyas Kinfemichael', 'email': 'mikikinfe345@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Mickiyas Kinfemichael', 'email': 'mikikinfe345@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1216', 'username': 'Mickiyas Kinfemichael', 'email': 'mikikinfe345@gmail.com'}}}}
# inserting user..... {'name': 'Mesfin Seyoum Dejenu', 'email': 'mesfinseyoum21@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Mesfin Seyoum Dejenu', 'email': 'mesfinseyoum21@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1217', 'username': 'Mesfin Seyoum Dejenu', 'email': 'mesfinseyoum21@gmail.com'}}}}
# inserting user..... {'name': 'Aschalew Mathewos Damtew', 'email': 'aschalewthecoder@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Aschalew Mathewos Damtew', 'email': 'aschalewthecoder@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1218', 'username': 'Aschalew Mathewos Damtew', 'email': 'aschalewthecoder@gmail.com'}}}}
# inserting user..... {'name': 'Menalyn Lesly Houndolo', 'email': 'leslyhoundolo@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Menalyn Lesly Houndolo', 'email': 'leslyhoundolo@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1219', 'username': 'Menalyn Lesly Houndolo', 'email': 'leslyhoundolo@gmail.com'}}}}
# inserting user..... {'name': 'Gebeyaw Tigabu', 'email': 'gebeyawtigabu88@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Gebeyaw Tigabu', 'email': 'gebeyawtigabu88@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1220', 'username': 'Gebeyaw Tigabu', 'email': 'gebeyawtigabu88@gmail.com'}}}}
# inserting user..... {'name': 'Temesgen Asmamaw', 'email': 'asmamawtemesgen16@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Temesgen Asmamaw', 'email': 'asmamawtemesgen16@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1221', 'username': 'Temesgen Asmamaw', 'email': 'asmamawtemesgen16@gmail.com'}}}}
# inserting user..... {'name': 'Mahider Tilahun', 'email': 'tilahunmahider46@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Mahider Tilahun', 'email': 'tilahunmahider46@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1222', 'username': 'Mahider Tilahun', 'email': 'tilahunmahider46@gmail.com'}}}}
# inserting user..... {'name': 'Bisrat Kebere', 'email': 'kiyyakebere@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Bisrat Kebere', 'email': 'kiyyakebere@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1223', 'username': 'Bisrat Kebere', 'email': 'kiyyakebere@gmail.com'}}}}
# Processed rows 1 to 20
# Pausing for 5 minutes...
# inserting user..... {'name': 'Azazh Wuletawu', 'email': 'azazhwuletaw@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Azazh Wuletawu', 'email': 'azazhwuletaw@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1224', 'username': 'Azazh Wuletawu', 'email': 'azazhwuletaw@gmail.com'}}}}
# inserting user..... {'name': 'Solomon Sala', 'email': 'tsegasolomon635@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Solomon Sala', 'email': 'tsegasolomon635@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1225', 'username': 'Solomon Sala', 'email': 'tsegasolomon635@gmail.com'}}}}
# inserting user..... {'name': 'Mihret Merid', 'email': 'mihretmruka21@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Mihret Merid', 'email': 'mihretmruka21@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1226', 'username': 'Mihret Merid', 'email': 'mihretmruka21@gmail.com'}}}}
# inserting user..... {'name': 'Jackson Muchiri', 'email': 'jackgachokam@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Jackson Muchiri', 'email': 'jackgachokam@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1227', 'username': 'Jackson Muchiri', 'email': 'jackgachokam@gmail.com'}}}}
# inserting user..... {'name': 'Tehir Gemechu', 'email': 'tahirsmart506@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Tehir Gemechu', 'email': 'tahirsmart506@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1228', 'username': 'Tehir Gemechu', 'email': 'tahirsmart506@gmail.com'}}}}
# inserting user..... {'name': 'Ruhama Israel', 'email': 'ruheezrael@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Ruhama Israel', 'email': 'ruheezrael@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1229', 'username': 'Ruhama Israel', 'email': 'ruheezrael@gmail.com'}}}}
# inserting user..... {'name': 'Araba Aman', 'email': 'harmetooo@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Araba Aman', 'email': 'harmetooo@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1230', 'username': 'Araba Aman', 'email': 'harmetooo@gmail.com'}}}}
# inserting user..... {'name': 'Nebiyu Biniyam Solomon', 'email': 'nebiyubiniyams@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Nebiyu Biniyam Solomon', 'email': 'nebiyubiniyams@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1231', 'username': 'Nebiyu Biniyam Solomon', 'email': 'nebiyubiniyams@gmail.com'}}}}
# inserting user..... {'name': 'Shemsu Heiru', 'email': 'shemsun2@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Shemsu Heiru', 'email': 'shemsun2@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1232', 'username': 'Shemsu Heiru', 'email': 'shemsun2@gmail.com'}}}}
# inserting user..... {'name': 'Biruk Wolde Amanauel', 'email': 'wbiruk@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Biruk Wolde Amanauel', 'email': 'wbiruk@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1233', 'username': 'Biruk Wolde Amanauel', 'email': 'wbiruk@gmail.com'}}}}
# inserting user..... {'name': 'Tsiyon Abera', 'email': 'tsiyon.mitiku24@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Tsiyon Abera', 'email': 'tsiyon.mitiku24@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1234', 'username': 'Tsiyon Abera', 'email': 'tsiyon.mitiku24@gmail.com'}}}}
# inserting user..... {'name': 'Beyene Likkisa', 'email': 'kassahun.beyene85@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Beyene Likkisa', 'email': 'kassahun.beyene85@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1235', 'username': 'Beyene Likkisa', 'email': 'kassahun.beyene85@gmail.com'}}}}
# inserting user..... {'name': 'Nardos Kefelegn', 'email': 'nardoskefelegn@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Nardos Kefelegn', 'email': 'nardoskefelegn@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1236', 'username': 'Nardos Kefelegn', 'email': 'nardoskefelegn@gmail.com'}}}}
# inserting user..... {'name': 'Yakob Yenie', 'email': 'yakobtsega@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Yakob Yenie', 'email': 'yakobtsega@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1237', 'username': 'Yakob Yenie', 'email': 'yakobtsega@gmail.com'}}}}
# inserting user..... {'name': 'Abraham Sahile', 'email': 'abresh.agit@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Abraham Sahile', 'email': 'abresh.agit@gmail.com'}
# result json {'errors': [{'message': 'Internal Server Error', 'extensions': {'code': 'INTERNAL_SERVER_ERROR'}}], 'data': None}
# ERROR: Could not create user.................... {'name': 'Abraham Sahile', 'email': 'abresh.agit@gmail.com', 'role': 'trainee', 'batch': 2}
# inserting user..... {'name': 'Yosef Shiferaw Birhane', 'email': 'yosefshiferaw19@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Yosef Shiferaw Birhane', 'email': 'yosefshiferaw19@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1238', 'username': 'Yosef Shiferaw Birhane', 'email': 'yosefshiferaw19@gmail.com'}}}}
# inserting user..... {'name': 'Murad Mohammed', 'email': 'yuusufmuraad800@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Murad Mohammed', 'email': 'yuusufmuraad800@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1239', 'username': 'Murad Mohammed', 'email': 'yuusufmuraad800@gmail.com'}}}}
# inserting user..... {'name': 'Medhanit Teshome Wodajo', 'email': 'medhanitworkneh@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Medhanit Teshome Wodajo', 'email': 'medhanitworkneh@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1240', 'username': 'Medhanit Teshome Wodajo', 'email': 'medhanitworkneh@gmail.com'}}}}
# inserting user..... {'name': 'Mareye Zeleke Mekonen', 'email': 'mareye132@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Mareye Zeleke Mekonen', 'email': 'mareye132@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1241', 'username': 'Mareye Zeleke Mekonen', 'email': 'mareye132@gmail.com'}}}}
# inserting user..... {'name': 'Nafol Abdisa', 'email': 'aponan122@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Nafol Abdisa', 'email': 'aponan122@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1242', 'username': 'Nafol Abdisa', 'email': 'aponan122@gmail.com'}}}}
# Processed rows 21 to 40
# Pausing for 5 minutes...
# inserting user..... {'name': 'Ruth Tsegaye', 'email': 'ruthtsegaye70@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Ruth Tsegaye', 'email': 'ruthtsegaye70@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1243', 'username': 'Ruth Tsegaye', 'email': 'ruthtsegaye70@gmail.com'}}}}
# inserting user..... {'name': 'Zemichael Moges', 'email': 'zemickeyx@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Zemichael Moges', 'email': 'zemickeyx@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1244', 'username': 'Zemichael Moges', 'email': 'zemickeyx@gmail.com'}}}}
# inserting user..... {'name': 'Samuel Aberra', 'email': 'samuelabera523@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Samuel Aberra', 'email': 'samuelabera523@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1245', 'username': 'Samuel Aberra', 'email': 'samuelabera523@gmail.com'}}}}
# inserting user..... {'name': 'Abenezer Tadesse', 'email': 'eshet22@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Abenezer Tadesse', 'email': 'eshet22@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1246', 'username': 'Abenezer Tadesse', 'email': 'eshet22@gmail.com'}}}}
# inserting user..... {'name': 'Hailemelekot Amsalu', 'email': 'ahailemelekot@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Hailemelekot Amsalu', 'email': 'ahailemelekot@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1247', 'username': 'Hailemelekot Amsalu', 'email': 'ahailemelekot@gmail.com'}}}}
# inserting user..... {'name': 'T Tunde A Fasasi', 'email': 'tlugodiva@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'T Tunde A Fasasi', 'email': 'tlugodiva@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1248', 'username': 'T Tunde A Fasasi', 'email': 'tlugodiva@gmail.com'}}}}
# inserting user..... {'name': 'Eyasu Achiso', 'email': 'eyasuachiso2@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Eyasu Achiso', 'email': 'eyasuachiso2@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1249', 'username': 'Eyasu Achiso', 'email': 'eyasuachiso2@gmail.com'}}}}
# inserting user..... {'name': 'Hailemariam Adugna', 'email': 'milkiitolasa2@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Hailemariam Adugna', 'email': 'milkiitolasa2@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1250', 'username': 'Hailemariam Adugna', 'email': 'milkiitolasa2@gmail.com'}}}}
# inserting user..... {'name': 'Melat Weldegebriel', 'email': 'melatwegebriel12@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Melat Weldegebriel', 'email': 'melatwegebriel12@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1251', 'username': 'Melat Weldegebriel', 'email': 'melatwegebriel12@gmail.com'}}}}
# inserting user..... {'name': 'Abenezer Teshome', 'email': 'ebenezerteshe05@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Abenezer Teshome', 'email': 'ebenezerteshe05@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1252', 'username': 'Abenezer Teshome', 'email': 'ebenezerteshe05@gmail.com'}}}}
# inserting user..... {'name': 'Tsega Abinet', 'email': 'sunny.tsega@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Tsega Abinet', 'email': 'sunny.tsega@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1253', 'username': 'Tsega Abinet', 'email': 'sunny.tsega@gmail.com'}}}}
# inserting user..... {'name': 'Saheed Oyelola', 'email': 'oyelola_saheed@yahoo.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Saheed Oyelola', 'email': 'oyelola_saheed@yahoo.com'}
# result json {'data': {'register': {'user': {'id': '1254', 'username': 'Saheed Oyelola', 'email': 'oyelola_saheed@yahoo.com'}}}}
# inserting user..... {'name': 'Owen Abuka', 'email': 'oc.abuka@gmail.com', 'role': 'trainee', 'batch': 2}
# passed variables ........... {'username': 'Owen Abuka', 'email': 'oc.abuka@gmail.com'}
# result json {'data': {'register': {'user': {'id': '1255', 'username': 'Owen Abuka', 'email': 'oc.abuka@gmail.com'}}}}
# Processed rows 41 to 60
# All records have been inserted successfully

# %%
# Read users with out alluser from Strapi
res_json = tip.cm.get_user_with_out_alluser(tip.sg, role= "Trainee")

# %%
res_json
# Out:
# {'data': {'usersPermissionsUsers': {'meta': {'pagination': {'total': 52}},
#    'data': [{'id': '1204',
#      'attributes': {'email': 'fabricenzamwitakuze1@gmail.com',
#       'username': 'Nzamwitakuze Fabrice',
#       'all_users': {'data': []}}},
#     {'id': '1205',
#      'attributes': {'email': 'lagrande997@gmail.com',
#       'username': 'Niwemutoni Gratia Laetitia',
#       'all_users': {'data': []}}},
#     {'id': '1206',
#      'attributes': {'email': 'edaoburtukan40@gmail.com',
#       'username': 'Burtukan Edao',
#       'all_users': {'data': []}}},
#     {'id': '1207',
#      'attributes': {'email': 'etornam339@gmail.com',
#       'username': 'Etornam Sika',
#       'all_users': {'data': []}}},
#     {'id': '1208',
#      'attributes': {'email': 'stacywairegi@gmail.com',
#       'username': 'Stacy Wairegi',
#       'all_users': {'data': []}}},
#     {'id': '1209',
#      'attributes': {'email': 'gechalex05@gmail.com',
#       'username': 'Getachew Alemayehu',
#       'all_users': {'data': []}}},
#     {'id': '1210',
#      'attributes': {'email': 'natoliadugnatafa@gmail.com',
#       'username': 'Natoli Adugna',
#       'all_users': {'data': []}}},
#     {'id': '1211',
#      'attributes': {'email': 'abelaw84@gmail.com',
#       'username': 'Abel Awelachew',
#       'all_users': {'data': []}}},
#     {'id': '1212',
#      'attributes': {'email': 'diboraabraham2@gmail.com',
#       'username': 'Dibora Abraham',
#       'all_users': {'data': []}}},
#     {'id': '1213',
#      'attributes': {'email': 'dagimmic97@gmail.com',
#       'username': 'Dagim Micheal',
#       'all_users': {'data': []}}},
#     {'id': '1214',
#      'attributes': {'email': 'didierharagirimana@gmail.com',
#       'username': 'Didier Haragirimana',
#       'all_users': {'data': []}}},
#     {'id': '1215',
#      'attributes': {'email': 'john.k.onyemaechi@outlook.com',
#       'username': 'John Kennedy Onyemaechi',
#       'all_users': {'data': []}}},
#     {'id': '1216',
#      'attributes': {'email': 'mikikinfe345@gmail.com',
#       'username': 'Mickiyas Kinfemichael',
#       'all_users': {'data': []}}},
#     {'id': '1217',
#      'attributes': {'email': 'mesfinseyoum21@gmail.com',
#       'username': 'Mesfin Seyoum Dejenu',
#       'all_users': {'data': []}}},
#     {'id': '1218',
#      'attributes': {'email': 'aschalewthecoder@gmail.com',
#       'username': 'Aschalew Mathewos Damtew',
#       'all_users': {'data': []}}},
#     {'id': '1219',
#      'attributes': {'email': 'leslyhoundolo@gmail.com',
#       'username': 'Menalyn Lesly Houndolo',
#       'all_users': {'data': []}}},
#     {'id': '1220',
#      'attributes': {'email': 'gebeyawtigabu88@gmail.com',
#       'username': 'Gebeyaw Tigabu',
#       'all_users': {'data': []}}},
#     {'id': '1221',
#      'attributes': {'email': 'asmamawtemesgen16@gmail.com',
#       'username': 'Temesgen Asmamaw',
#       'all_users': {'data': []}}},
#     {'id': '1222',
#      'attributes': {'email': 'tilahunmahider46@gmail.com',
#       'username': 'Mahider Tilahun',
#       'all_users': {'data': []}}},
#     {'id': '1223',
#      'attributes': {'email': 'kiyyakebere@gmail.com',
#       'username': 'Bisrat Kebere',
#       'all_users': {'data': []}}},
#     {'id': '1224',
#      'attributes': {'email': 'azazhwuletaw@gmail.com',
#       'username': 'Azazh Wuletawu',
#       'all_users': {'data': []}}},
#     {'id': '1225',
#      'attributes': {'email': 'tsegasolomon635@gmail.com',
#       'username': 'Solomon Sala',
#       'all_users': {'data': []}}},
#     {'id': '1226',
#      'attributes': {'email': 'mihretmruka21@gmail.com',
#       'username': 'Mihret Merid',
#       'all_users': {'data': []}}},
#     {'id': '1227',
#      'attributes': {'email': 'jackgachokam@gmail.com',
#       'username': 'Jackson Muchiri',
#       'all_users': {'data': []}}},
#     {'id': '1228',
#      'attributes': {'email': 'tahirsmart506@gmail.com',
#       'username': 'Tehir Gemechu',
#       'all_users': {'data': []}}},
#     {'id': '1229',
#      'attributes': {'email': 'ruheezrael@gmail.com',
#       'username': 'Ruhama Israel',
#       'all_users': {'data': []}}},
#     {'id': '1230',
#      'attributes': {'email': 'harmetooo@gmail.com',
#       'username': 'Araba Aman',
#       'all_users': {'data': []}}},
#     {'id': '1231',
#      'attributes': {'email': 'nebiyubiniyams@gmail.com',
#       'username': 'Nebiyu Biniyam Solomon',
#       'all_users': {'data': []}}},
#     {'id': '1232',
#      'attributes': {'email': 'shemsun2@gmail.com',
#       'username': 'Shemsu Heiru',
#       'all_users': {'data': []}}},
#     {'id': '1233',
#      'attributes': {'email': 'wbiruk@gmail.com',
#       'username': 'Biruk Wolde Amanauel',
#       'all_users': {'data': []}}},
#     {'id': '1234',
#      'attributes': {'email': 'tsiyon.mitiku24@gmail.com',
#       'username': 'Tsiyon Abera',
#       'all_users': {'data': []}}},
#     {'id': '1235',
#      'attributes': {'email': 'kassahun.beyene85@gmail.com',
#       'username': 'Beyene Likkisa',
#       'all_users': {'data': []}}},
#     {'id': '1236',
#      'attributes': {'email': 'nardoskefelegn@gmail.com',
#       'username': 'Nardos Kefelegn',
#       'all_users': {'data': []}}},
#     {'id': '1237',
#      'attributes': {'email': 'yakobtsega@gmail.com',
#       'username': 'Yakob Yenie',
#       'all_users': {'data': []}}},
#     {'id': '1238',
#      'attributes': {'email': 'yosefshiferaw19@gmail.com',
#       'username': 'Yosef Shiferaw Birhane',
#       'all_users': {'data': []}}},
#     {'id': '1239',
#      'attributes': {'email': 'yuusufmuraad800@gmail.com',
#       'username': 'Murad Mohammed',
#       'all_users': {'data': []}}},
#     {'id': '1240',
#      'attributes': {'email': 'medhanitworkneh@gmail.com',
#       'username': 'Medhanit Teshome Wodajo',
#       'all_users': {'data': []}}},
#     {'id': '1241',
#      'attributes': {'email': 'mareye132@gmail.com',
#       'username': 'Mareye Zeleke Mekonen',
#       'all_users': {'data': []}}},
#     {'id': '1242',
#      'attributes': {'email': 'aponan122@gmail.com',
#       'username': 'Nafol Abdisa',
#       'all_users': {'data': []}}},
#     {'id': '1243',
#      'attributes': {'email': 'ruthtsegaye70@gmail.com',
#       'username': 'Ruth Tsegaye',
#       'all_users': {'data': []}}},
#     {'id': '1244',
#      'attributes': {'email': 'zemickeyx@gmail.com',
#       'username': 'Zemichael Moges',
#       'all_users': {'data': []}}},
#     {'id': '1245',
#      'attributes': {'email': 'samuelabera523@gmail.com',
#       'username': 'Samuel Aberra',
#       'all_users': {'data': []}}},
#     {'id': '1246',
#      'attributes': {'email': 'eshet22@gmail.com',
#       'username': 'Abenezer Tadesse',
#       'all_users': {'data': []}}},
#     {'id': '1247',
#      'attributes': {'email': 'ahailemelekot@gmail.com',
#       'username': 'Hailemelekot Amsalu',
#       'all_users': {'data': []}}},
#     {'id': '1248',
#      'attributes': {'email': 'tlugodiva@gmail.com',
#       'username': 'T Tunde A Fasasi',
#       'all_users': {'data': []}}},
#     {'id': '1249',
#      'attributes': {'email': 'eyasuachiso2@gmail.com',
#       'username': 'Eyasu Achiso',
#       'all_users': {'data': []}}},
#     {'id': '1250',
#      'attributes': {'email': 'milkiitolasa2@gmail.com',
#       'username': 'Hailemariam Adugna',
#       'all_users': {'data': []}}},
#     {'id': '1251',
#      'attributes': {'email': 'melatwegebriel12@gmail.com',
#       'username': 'Melat Weldegebriel',
#       'all_users': {'data': []}}},
#     {'id': '1252',
#      'attributes': {'email': 'ebenezerteshe05@gmail.com',
#       'username': 'Abenezer Teshome',
#       'all_users': {'data': []}}},
#     {'id': '1253',
#      'attributes': {'email': 'sunny.tsega@gmail.com',
#       'username': 'Tsega Abinet',
#       'all_users': {'data': []}}},
#     {'id': '1254',
#      'attributes': {'email': 'oyelola_saheed@yahoo.com',
#       'username': 'Saheed Oyelola',
#       'all_users': {'data': []}}},
#     {'id': '1255',
#      'attributes': {'email': 'oc.abuka@gmail.com',
#       'username': 'Owen Abuka',
#       'all_users': {'data': []}}}]}}}

# %%
import pandas as pd
def parse_trainee_info(res_json):
    trainee_info = []
    for i in res_json['data']['usersPermissionsUsers']['data']:
        params = {
            'userId': i['id'],
            'email': i['attributes']['email'],
            'name': i['attributes']['username']
        }
        trainee_info.append(params)
    df = pd.DataFrame(trainee_info)
    df['batch']= u2j_batch2_trainee_config.batch
    df['role']= "trainee"
    return df

# %%
df = parse_trainee_info(res_json)

# %%
df
# Out:
#    userId                           email                        name  batch  \
# 0    1204  fabricenzamwitakuze1@gmail.com        Nzamwitakuze Fabrice      2
# 1    1205           lagrande997@gmail.com  Niwemutoni Gratia Laetitia      2
# 2    1206        edaoburtukan40@gmail.com               Burtukan Edao      2
# 3    1207            etornam339@gmail.com                Etornam Sika      2
# 4    1208          stacywairegi@gmail.com               Stacy Wairegi      2
# 5    1209            gechalex05@gmail.com          Getachew Alemayehu      2
# 6    1210      natoliadugnatafa@gmail.com               Natoli Adugna      2
# 7    1211              abelaw84@gmail.com              Abel Awelachew      2
#
#        role
# 0   trainee
# 1   trainee
# 2   trainee
# 3   trainee
# 4   trainee
# 5   trainee
# 6   trainee
# 7   trainee
# 8   trainee
# 9   trainee
# 10  trainee
# 11  trainee
# 12  trainee
# 13  trainee
# 14  trainee
# 15  trainee
# 16  trainee
# 17  trainee
# 18  trainee
# 19  trainee
# 20  trainee
# 21  trainee
# 22  trainee
# 23  trainee
# 24  trainee
# 25  trainee
# 26  trainee
# 27  trainee
# 28  trainee
# 29  trainee
# 30  trainee
# 31  trainee
# 32  trainee
# 33  trainee
# 34  trainee
# 35  trainee
# 36  trainee
# 37  trainee
# 38  trainee
# 39  trainee
# 40  trainee
# 41  trainee
# 42  trainee
# 43  trainee
# 44  trainee
# 45  trainee
# 46  trainee
# 47  trainee
# 48  trainee
# 49  trainee
# 50  trainee
# 51  trainee

# %%
### insert all user 
import time
for i, row in df.iterrows():
    res_dict = {
        "name": row['name'],
        "email": row['email'],
        "role": row['role'],
        "batch": row['batch'],
        "userId": row['userId']
    }
    print(res_dict)
    res = tip.cm.insert_all_users(tip.sg, res_dict)
    print(res)
    if i % 50 == 0:
        time.sleep(10)
# Out:
# {'name': 'Nzamwitakuze Fabrice', 'email': 'fabricenzamwitakuze1@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1204'}
# {'data': {'createAllUser': {'data': {'id': '1203'}}}}
# {'name': 'Niwemutoni Gratia Laetitia', 'email': 'lagrande997@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1205'}
# {'data': {'createAllUser': {'data': {'id': '1204'}}}}
# {'name': 'Burtukan Edao', 'email': 'edaoburtukan40@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1206'}
# {'data': {'createAllUser': {'data': {'id': '1205'}}}}
# {'name': 'Etornam Sika', 'email': 'etornam339@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1207'}
# {'data': {'createAllUser': {'data': {'id': '1206'}}}}
# {'name': 'Stacy Wairegi', 'email': 'stacywairegi@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1208'}
# {'data': {'createAllUser': {'data': {'id': '1207'}}}}
# {'name': 'Getachew Alemayehu', 'email': 'gechalex05@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1209'}
# {'data': {'createAllUser': {'data': {'id': '1208'}}}}
# {'name': 'Natoli Adugna', 'email': 'natoliadugnatafa@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1210'}
# {'data': {'createAllUser': {'data': {'id': '1209'}}}}
# {'name': 'Abel Awelachew', 'email': 'abelaw84@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1211'}
# {'data': {'createAllUser': {'data': {'id': '1210'}}}}
# {'name': 'Dibora Abraham', 'email': 'diboraabraham2@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1212'}
# {'data': {'createAllUser': {'data': {'id': '1211'}}}}
# {'name': 'Dagim Micheal', 'email': 'dagimmic97@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1213'}
# {'data': {'createAllUser': {'data': {'id': '1212'}}}}
# {'name': 'Didier Haragirimana', 'email': 'didierharagirimana@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1214'}
# {'data': {'createAllUser': {'data': {'id': '1213'}}}}
# {'name': 'John Kennedy Onyemaechi', 'email': 'john.k.onyemaechi@outlook.com', 'role': 'trainee', 'batch': 2, 'userId': '1215'}
# {'data': {'createAllUser': {'data': {'id': '1214'}}}}
# {'name': 'Mickiyas Kinfemichael', 'email': 'mikikinfe345@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1216'}
# {'data': {'createAllUser': {'data': {'id': '1215'}}}}
# {'name': 'Mesfin Seyoum Dejenu', 'email': 'mesfinseyoum21@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1217'}
# {'data': {'createAllUser': {'data': {'id': '1216'}}}}
# {'name': 'Aschalew Mathewos Damtew', 'email': 'aschalewthecoder@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1218'}
# {'data': {'createAllUser': {'data': {'id': '1217'}}}}
# {'name': 'Menalyn Lesly Houndolo', 'email': 'leslyhoundolo@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1219'}
# {'data': {'createAllUser': {'data': {'id': '1218'}}}}
# {'name': 'Gebeyaw Tigabu', 'email': 'gebeyawtigabu88@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1220'}
# {'data': {'createAllUser': {'data': {'id': '1219'}}}}
# {'name': 'Temesgen Asmamaw', 'email': 'asmamawtemesgen16@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1221'}
# {'data': {'createAllUser': {'data': {'id': '1220'}}}}
# {'name': 'Mahider Tilahun', 'email': 'tilahunmahider46@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1222'}
# {'data': {'createAllUser': {'data': {'id': '1221'}}}}
# {'name': 'Bisrat Kebere', 'email': 'kiyyakebere@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1223'}
# {'data': {'createAllUser': {'data': {'id': '1222'}}}}
# {'name': 'Azazh Wuletawu', 'email': 'azazhwuletaw@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1224'}
# {'data': {'createAllUser': {'data': {'id': '1223'}}}}
# {'name': 'Solomon Sala', 'email': 'tsegasolomon635@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1225'}
# {'data': {'createAllUser': {'data': {'id': '1224'}}}}
# {'name': 'Mihret Merid', 'email': 'mihretmruka21@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1226'}
# {'data': {'createAllUser': {'data': {'id': '1225'}}}}
# {'name': 'Jackson Muchiri', 'email': 'jackgachokam@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1227'}
# {'data': {'createAllUser': {'data': {'id': '1226'}}}}
# {'name': 'Tehir Gemechu', 'email': 'tahirsmart506@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1228'}
# {'data': {'createAllUser': {'data': {'id': '1227'}}}}
# {'name': 'Ruhama Israel', 'email': 'ruheezrael@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1229'}
# {'data': {'createAllUser': {'data': {'id': '1228'}}}}
# {'name': 'Araba Aman', 'email': 'harmetooo@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1230'}
# {'data': {'createAllUser': {'data': {'id': '1229'}}}}
# {'name': 'Nebiyu Biniyam Solomon', 'email': 'nebiyubiniyams@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1231'}
# {'data': {'createAllUser': {'data': {'id': '1230'}}}}
# {'name': 'Shemsu Heiru', 'email': 'shemsun2@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1232'}
# {'data': {'createAllUser': {'data': {'id': '1231'}}}}
# {'name': 'Biruk Wolde Amanauel', 'email': 'wbiruk@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1233'}
# {'data': {'createAllUser': {'data': {'id': '1232'}}}}
# {'name': 'Tsiyon Abera', 'email': 'tsiyon.mitiku24@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1234'}
# {'data': {'createAllUser': {'data': {'id': '1233'}}}}
# {'name': 'Beyene Likkisa', 'email': 'kassahun.beyene85@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1235'}
# {'data': {'createAllUser': {'data': {'id': '1234'}}}}
# {'name': 'Nardos Kefelegn', 'email': 'nardoskefelegn@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1236'}
# {'data': {'createAllUser': {'data': {'id': '1235'}}}}
# {'name': 'Yakob Yenie', 'email': 'yakobtsega@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1237'}
# {'data': {'createAllUser': {'data': {'id': '1236'}}}}
# {'name': 'Yosef Shiferaw Birhane', 'email': 'yosefshiferaw19@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1238'}
# {'data': {'createAllUser': {'data': {'id': '1237'}}}}
# {'name': 'Murad Mohammed', 'email': 'yuusufmuraad800@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1239'}
# {'data': {'createAllUser': {'data': {'id': '1238'}}}}
# {'name': 'Medhanit Teshome Wodajo', 'email': 'medhanitworkneh@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1240'}
# {'data': {'createAllUser': {'data': {'id': '1239'}}}}
# {'name': 'Mareye Zeleke Mekonen', 'email': 'mareye132@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1241'}
# {'data': {'createAllUser': {'data': {'id': '1240'}}}}
# {'name': 'Nafol Abdisa', 'email': 'aponan122@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1242'}
# {'data': {'createAllUser': {'data': {'id': '1241'}}}}
# {'name': 'Ruth Tsegaye', 'email': 'ruthtsegaye70@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1243'}
# {'data': {'createAllUser': {'data': {'id': '1242'}}}}
# {'name': 'Zemichael Moges', 'email': 'zemickeyx@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1244'}
# {'data': {'createAllUser': {'data': {'id': '1243'}}}}
# {'name': 'Samuel Aberra', 'email': 'samuelabera523@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1245'}
# {'data': {'createAllUser': {'data': {'id': '1244'}}}}
# {'name': 'Abenezer Tadesse', 'email': 'eshet22@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1246'}
# {'data': {'createAllUser': {'data': {'id': '1245'}}}}
# {'name': 'Hailemelekot Amsalu', 'email': 'ahailemelekot@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1247'}
# {'data': {'createAllUser': {'data': {'id': '1246'}}}}
# {'name': 'T Tunde A Fasasi', 'email': 'tlugodiva@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1248'}
# {'data': {'createAllUser': {'data': {'id': '1247'}}}}
# {'name': 'Eyasu Achiso', 'email': 'eyasuachiso2@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1249'}
# {'data': {'createAllUser': {'data': {'id': '1248'}}}}
# {'name': 'Hailemariam Adugna', 'email': 'milkiitolasa2@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1250'}
# {'data': {'createAllUser': {'data': {'id': '1249'}}}}
# {'name': 'Melat Weldegebriel', 'email': 'melatwegebriel12@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1251'}
# {'data': {'createAllUser': {'data': {'id': '1250'}}}}
# {'name': 'Abenezer Teshome', 'email': 'ebenezerteshe05@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1252'}
# {'data': {'createAllUser': {'data': {'id': '1251'}}}}
# {'name': 'Tsega Abinet', 'email': 'sunny.tsega@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1253'}
# {'data': {'createAllUser': {'data': {'id': '1252'}}}}
# {'name': 'Saheed Oyelola', 'email': 'oyelola_saheed@yahoo.com', 'role': 'trainee', 'batch': 2, 'userId': '1254'}
# {'data': {'createAllUser': {'data': {'id': '1253'}}}}
# {'name': 'Owen Abuka', 'email': 'oc.abuka@gmail.com', 'role': 'trainee', 'batch': 2, 'userId': '1255'}
# {'data': {'createAllUser': {'data': {'id': '1254'}}}}

# %% [markdown]
# ### Insert Group

# %%
adf = tip.select_batch_users_from_allusers()

# %%
adf
# Out:
#     all_user                        Email  batches attributes.user.data.id  \
# 0        585     abelataguta001@gmail.com        2                     586
# 1        586  42958253@mylife.unisa.ac.za        2                     587
# 2        587        abdiikenesa@gmail.com        2                     588
# 3        588   apdifatahahmed02@gmail.com        2                     589
# 4        589         wiilwaaljr@gmail.com        2                     590
# ..       ...                          ...      ...                     ...
# 660     1250   melatwegebriel12@gmail.com        2                    1251
# 661     1251    ebenezerteshe05@gmail.com        2                    1252
# 662     1252        sunny.tsega@gmail.com        2                    1253
# 663     1253     oyelola_saheed@yahoo.com        2                    1254
# 664     1254           oc.abuka@gmail.com        2                    1255
#
#     attributes.user.data.attributes.email
# 0                abelataguta001@gmail.com
# 1             42958253@mylife.unisa.ac.za
# 2                   abdiikenesa@gmail.com
# 3              apdifatahahmed02@gmail.com
# 4                    wiilwaaljr@gmail.com
# ..                                    ...
# 660            melatwegebriel12@gmail.com
# 661             ebenezerteshe05@gmail.com
# 662                 sunny.tsega@gmail.com
# 663              oyelola_saheed@yahoo.com
# 664                    oc.abuka@gmail.com
#
# [665 rows x 5 columns]

# %%
tip.configs.batch
# Out:
# 2

# %%
### New group
tip.insert_group()
# Out:
# https://u2jcms.10academy.org/api/groups
# {'data': {'id': 3, 'attributes': {'Name': 'B2', 'createdAt': '2024-07-27T13:48:10.672Z', 'updatedAt': '2024-07-27T13:48:10.672Z'}}, 'meta': {}}

# %%
### to update existing group
def get_all_user_without_group ():
    query = """query getallUserID{
    allUsers(
        pagination:{start:0,limit:2000}
        filters:{groups:{id:{eq:null}}}){
        meta{
        pagination{
            total
        }
        }
        data{
        id
        }
    }
    }"""
    result_json = tip.sg.Select_from_table(query=query, variables=None)
    without_group = [str(i['id']) for i in result_json['data']['allUsers']['data']]
    return without_group

# %%
without_group = get_all_user_without_group ()
len( without_group)
# Out:
# 52

# %%
#get_allUser_by_groupId(groupId)
def get_allUser_by_groupId( groupId):
    query = """query getallUserID($groupID:ID){
      allUsers(
        pagination:{start:0,limit:2000}
        filters:{groups:{id:{eq:$groupID}}}){
        meta{
          pagination{
            total
          }
        }
        data{
          id
        }
      }
    }"""
    resu_json = tip.sg.Select_from_table(query=query, variables={"groupID":groupId})
    with_group = [str(i['id']) for i in resu_json['data']['allUsers']['data']]
    return with_group

# %%
with_group = get_allUser_by_groupId(groupId=3)

# %%
len(with_group)
# Out:
# 618

# %%
all_users_for_group = without_group + with_group

# %%
len(all_users_for_group)
# Out:
# 670

# %%
def update_batch_user_for_group(groupid : int, all_users_for_group):
  update_query = """mutation updateGroup($groupID:ID!,$allusersID:[ID]){
  updateGroup(id:$groupID,data:{all_users:$allusersID}){
    data{
      id
    }
  }
  }"""
  resu_json = sg.Select_from_table(query=update_query, variables={"groupID":groupid,"allusersID":all_users_for_group})
  print(resu_json)

# %%
update_batch_user_for_group(groupid=3, all_users_for_group=all_users_for_group )
# Out:
# {'data': {'updateGroup': {'data': {'id': '3'}}}}

# %% [markdown]
# ### Trainee Inserstion

# %%
batch = tip.get_batch()

# %%
# batch = tip.get_batch()
adf = tip.select_batch_users_from_allusers()

# %%
batch
# Out:
# 2

# %%
def select_alluseers_without_trainee():
    adf = tip.select_batch_users_from_allusers()
    adf.rename(columns={"Email":"email"}, inplace=True)
    adf = adf[['all_user','email']]
    ddf = tip.prepare_applicants()
    new_trainees = ddf['email'].to_list()
    dfx = adf[adf['email'].isin(new_trainees)]
    return dfx

# %%
dfx =  select_alluseers_without_trainee()
# Out:
# gdrive.py:__init__:99: get_auth(ssmkey=gspread/config, envvar=GSPREAD_CONFIG, fconfig=~/.env/gclass_credentials.json)
# reading auth from file: /var/folders/dp/57y4rbx55kxdswwsnmzgp_j40000gn/T/gclass_credentials.json ..
# ****** using service account: ~/.env/gclass_credentials.json
# service account is being used without delegation..
# ------------u2j-batch2 - Week 5 df.shape=(53, 4)----
# /Users/mahlettaye/miniconda3/envs/pjmatch/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
dfx
# Out:
#     all_user                           email
# 613     1203  fabricenzamwitakuze1@gmail.com
# 614     1204           lagrande997@gmail.com
# 615     1205        edaoburtukan40@gmail.com
# 616     1206            etornam339@gmail.com
# 617     1207          stacywairegi@gmail.com
# 618     1208            gechalex05@gmail.com
# 619     1209      natoliadugnatafa@gmail.com
# 620     1210              abelaw84@gmail.com
# 621     1211        diboraabraham2@gmail.com
# 622     1212            dagimmic97@gmail.com
# 623     1213    didierharagirimana@gmail.com
# 624     1214   john.k.onyemaechi@outlook.com
# 625     1215          mikikinfe345@gmail.com
# 626     1216        mesfinseyoum21@gmail.com
# 627     1217      aschalewthecoder@gmail.com
# 628     1218         leslyhoundolo@gmail.com
# 629     1219       gebeyawtigabu88@gmail.com
# 630     1220     asmamawtemesgen16@gmail.com
# 631     1221      tilahunmahider46@gmail.com
# 632     1222           kiyyakebere@gmail.com
# 633     1223          azazhwuletaw@gmail.com
# 634     1224       tsegasolomon635@gmail.com
# 635     1225         mihretmruka21@gmail.com
# 636     1226          jackgachokam@gmail.com
# 637     1227         tahirsmart506@gmail.com
# 638     1228            ruheezrael@gmail.com
# 639     1229             harmetooo@gmail.com
# 640     1230        nebiyubiniyams@gmail.com
# 641     1231              shemsun2@gmail.com
# 642     1232                wbiruk@gmail.com
# 643     1233       tsiyon.mitiku24@gmail.com
# 644     1234     kassahun.beyene85@gmail.com
# 645     1235        nardoskefelegn@gmail.com
# 646     1236            yakobtsega@gmail.com
# 647     1237       yosefshiferaw19@gmail.com
# 648     1238       yuusufmuraad800@gmail.com
# 649     1239       medhanitworkneh@gmail.com
# 650     1240             mareye132@gmail.com
# 651     1241             aponan122@gmail.com
# 652     1242         ruthtsegaye70@gmail.com
# 653     1243             zemickeyx@gmail.com
# 654     1244        samuelabera523@gmail.com
# 655     1245               eshet22@gmail.com
# 656     1246         ahailemelekot@gmail.com
# 657     1247             tlugodiva@gmail.com
# 658     1248          eyasuachiso2@gmail.com
# 659     1249         milkiitolasa2@gmail.com
# 660     1250      melatwegebriel12@gmail.com
# 661     1251       ebenezerteshe05@gmail.com
# 662     1252           sunny.tsega@gmail.com
# 663     1253        oyelola_saheed@yahoo.com
# 664     1254              oc.abuka@gmail.com

# %%
adf
# Out:
#     all_user                        Email  batches attributes.user.data.id  \
# 0        585     abelataguta001@gmail.com        2                     586
# 1        586  42958253@mylife.unisa.ac.za        2                     587
# 2        587        abdiikenesa@gmail.com        2                     588
# 3        588   apdifatahahmed02@gmail.com        2                     589
# 4        589         wiilwaaljr@gmail.com        2                     590
# ..       ...                          ...      ...                     ...
# 660     1250   melatwegebriel12@gmail.com        2                    1251
# 661     1251    ebenezerteshe05@gmail.com        2                    1252
# 662     1252        sunny.tsega@gmail.com        2                    1253
# 663     1253     oyelola_saheed@yahoo.com        2                    1254
# 664     1254           oc.abuka@gmail.com        2                    1255
#
#     attributes.user.data.attributes.email
# 0                abelataguta001@gmail.com
# 1             42958253@mylife.unisa.ac.za
# 2                   abdiikenesa@gmail.com
# 3              apdifatahahmed02@gmail.com
# 4                    wiilwaaljr@gmail.com
# ..                                    ...
# 660            melatwegebriel12@gmail.com
# 661             ebenezerteshe05@gmail.com
# 662                 sunny.tsega@gmail.com
# 663              oyelola_saheed@yahoo.com
# 664                    oc.abuka@gmail.com
#
# [665 rows x 5 columns]

# %%
dfx['batch'] =  str(batch)
### create UUID for all trainee
dfx['trainee_id'] = dfx['email'].apply(lambda x: tip.generate_uuid())
dfx['Status'] ="Accepted"

# %%
dfx
# Out:
#     all_user                           email batch  \
# 613     1203  fabricenzamwitakuze1@gmail.com     2
# 614     1204           lagrande997@gmail.com     2
# 615     1205        edaoburtukan40@gmail.com     2
# 616     1206            etornam339@gmail.com     2
# 617     1207          stacywairegi@gmail.com     2
# 618     1208            gechalex05@gmail.com     2
# 619     1209      natoliadugnatafa@gmail.com     2
# 620     1210              abelaw84@gmail.com     2
# 621     1211        diboraabraham2@gmail.com     2
# 622     1212            dagimmic97@gmail.com     2
# 623     1213    didierharagirimana@gmail.com     2
# 624     1214   john.k.onyemaechi@outlook.com     2
# 625     1215          mikikinfe345@gmail.com     2
# 626     1216        mesfinseyoum21@gmail.com     2
# 627     1217      aschalewthecoder@gmail.com     2
# 628     1218         leslyhoundolo@gmail.com     2
# 629     1219       gebeyawtigabu88@gmail.com     2
# 630     1220     asmamawtemesgen16@gmail.com     2
# 631     1221      tilahunmahider46@gmail.com     2
# 632     1222           kiyyakebere@gmail.com     2
# 633     1223          azazhwuletaw@gmail.com     2
# 634     1224       tsegasolomon635@gmail.com     2
# 635     1225         mihretmruka21@gmail.com     2
# 636     1226          jackgachokam@gmail.com     2
# 637     1227         tahirsmart506@gmail.com     2
# 638     1228            ruheezrael@gmail.com     2
# 639     1229             harmetooo@gmail.com     2
# 640     1230        nebiyubiniyams@gmail.com     2
# 641     1231              shemsun2@gmail.com     2
# 642     1232                wbiruk@gmail.com     2
# 643     1233       tsiyon.mitiku24@gmail.com     2
# 644     1234     kassahun.beyene85@gmail.com     2
# 645     1235        nardoskefelegn@gmail.com     2
# 646     1236            yakobtsega@gmail.com     2
# 647     1237       yosefshiferaw19@gmail.com     2
# 648     1238       yuusufmuraad800@gmail.com     2
# 649     1239       medhanitworkneh@gmail.com     2
# 650     1240             mareye132@gmail.com     2
# 651     1241             aponan122@gmail.com     2
# 652     1242         ruthtsegaye70@gmail.com     2
# 653     1243             zemickeyx@gmail.com     2
# 654     1244        samuelabera523@gmail.com     2
# 655     1245               eshet22@gmail.com     2
# 656     1246         ahailemelekot@gmail.com     2
# 657     1247             tlugodiva@gmail.com     2
# 658     1248          eyasuachiso2@gmail.com     2
# 659     1249         milkiitolasa2@gmail.com     2
# 660     1250      melatwegebriel12@gmail.com     2
# 661     1251       ebenezerteshe05@gmail.com     2
# 653  6a1fd9fc-0963-4d3c-b7c8-0d969af32341  Accepted
# 654  76048e66-5509-4fee-8a38-000e57ce467d  Accepted
# 655  42b95ad9-6fa5-4bd8-8eee-ba7cf6dfd4b5  Accepted
# 656  8249ea3e-98ef-498c-91cc-cf0d55cf1c5c  Accepted
# 657  8351a155-6879-4342-83b7-4b9476388f38  Accepted
# 658  d98a2ae1-5f53-45bc-b7d9-dbaf67bf5068  Accepted
# 659  40857014-cbc6-4ab9-8b91-80343b8fe481  Accepted
# 660  5e8a478d-0f19-4e54-9ed7-5869b4108f11  Accepted
# 661  54adfc2d-4217-440c-9921-07097517c420  Accepted
# 662  017b9256-1de2-4c09-ae15-ddef366aaf15  Accepted
# 663  f6d02b45-faed-4d9e-a1ad-8130487cc3f5  Accepted
# 664  f96a3bf4-0669-4439-8835-b8bff1ac6ad3  Accepted

# %%
import json
## To update trainee with exiting batch
def add_new_trainee_exiting_batch(dfx):
    print("INFO:Total number of newly accepted with trainee ",dfx.shape)
    result = dfx.to_json(orient="records", date_format = 'iso')

    # url = f"https://{self.root}.10academy.org/api/trainees"
    url = "trainees"

    for single in json.loads(result):
        print(single)
        r= tip.sm.insert_data(single,url)
        print(r)

    print("All records have been inserted successfully")

# %%
add_new_trainee_exiting_batch(dfx)
# Out:
# INFO:Total number of newly accepted with trainee  (52, 5)
# {'all_user': '1203', 'email': 'fabricenzamwitakuze1@gmail.com', 'batch': '2', 'trainee_id': 'bc6a6b52-40b0-4ec8-a2b5-f601dce823d4', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1172, 'attributes': {'email': 'fabricenzamwitakuze1@gmail.com', 'createdAt': '2024-08-25T14:17:55.077Z', 'updatedAt': '2024-08-25T14:17:55.077Z', 'trainee_id': 'bc6a6b52-40b0-4ec8-a2b5-f601dce823d4', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1204', 'email': 'lagrande997@gmail.com', 'batch': '2', 'trainee_id': 'f5d77294-80f5-4c3e-8164-0e04779802d8', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1173, 'attributes': {'email': 'lagrande997@gmail.com', 'createdAt': '2024-08-25T14:17:56.076Z', 'updatedAt': '2024-08-25T14:17:56.076Z', 'trainee_id': 'f5d77294-80f5-4c3e-8164-0e04779802d8', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1205', 'email': 'edaoburtukan40@gmail.com', 'batch': '2', 'trainee_id': 'c2c75912-f1d3-417d-af10-18187399892f', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1174, 'attributes': {'email': 'edaoburtukan40@gmail.com', 'createdAt': '2024-08-25T14:17:57.031Z', 'updatedAt': '2024-08-25T14:17:57.031Z', 'trainee_id': 'c2c75912-f1d3-417d-af10-18187399892f', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1206', 'email': 'etornam339@gmail.com', 'batch': '2', 'trainee_id': '47cad8a5-7361-4e3d-a515-0d9d2fb50eea', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1175, 'attributes': {'email': 'etornam339@gmail.com', 'createdAt': '2024-08-25T14:17:58.000Z', 'updatedAt': '2024-08-25T14:17:58.000Z', 'trainee_id': '47cad8a5-7361-4e3d-a515-0d9d2fb50eea', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1207', 'email': 'stacywairegi@gmail.com', 'batch': '2', 'trainee_id': '1274356a-3b42-4cd3-b9c8-7cf62e60e03a', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 
 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1249', 'email': 'milkiitolasa2@gmail.com', 'batch': '2', 'trainee_id': '40857014-cbc6-4ab9-8b91-80343b8fe481', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1218, 'attributes': {'email': 'milkiitolasa2@gmail.com', 'createdAt': '2024-08-25T14:18:40.503Z', 'updatedAt': '2024-08-25T14:18:40.503Z', 'trainee_id': '40857014-cbc6-4ab9-8b91-80343b8fe481', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1250', 'email': 'melatwegebriel12@gmail.com', 'batch': '2', 'trainee_id': '5e8a478d-0f19-4e54-9ed7-5869b4108f11', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1219, 'attributes': {'email': 'melatwegebriel12@gmail.com', 'createdAt': '2024-08-25T14:18:42.483Z', 'updatedAt': '2024-08-25T14:18:42.483Z', 'trainee_id': '5e8a478d-0f19-4e54-9ed7-5869b4108f11', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1251', 'email': 'ebenezerteshe05@gmail.com', 'batch': '2', 'trainee_id': '54adfc2d-4217-440c-9921-07097517c420', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1220, 'attributes': {'email': 'ebenezerteshe05@gmail.com', 'createdAt': '2024-08-25T14:18:43.450Z', 'updatedAt': '2024-08-25T14:18:43.450Z', 'trainee_id': '54adfc2d-4217-440c-9921-07097517c420', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1252', 'email': 'sunny.tsega@gmail.com', 'batch': '2', 'trainee_id': '017b9256-1de2-4c09-ae15-ddef366aaf15', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1221, 'attributes': {'email': 'sunny.tsega@gmail.com', 'createdAt': '2024-08-25T14:18:44.605Z', 'updatedAt': '2024-08-25T14:18:44.605Z', 'trainee_id': '017b9256-1de2-4c09-ae15-ddef366aaf15', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1253', 'email': 'oyelola_saheed@yahoo.com', 'batch': '2', 'trainee_id': 'f6d02b45-faed-4d9e-a1ad-8130487cc3f5', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1222, 'attributes': {'email': 'oyelola_saheed@yahoo.com', 'createdAt': '2024-08-25T14:18:45.632Z', 'updatedAt': '2024-08-25T14:18:45.632Z', 'trainee_id': 'f6d02b45-faed-4d9e-a1ad-8130487cc3f5', 'Status': 'Accepted'}}, 'meta': {}}
# {'all_user': '1254', 'email': 'oc.abuka@gmail.com', 'batch': '2', 'trainee_id': 'f96a3bf4-0669-4439-8835-b8bff1ac6ad3', 'Status': 'Accepted'}
# https://u2jcms.10academy.org/api/trainees
# {'data': {'id': 1223, 'attributes': {'email': 'oc.abuka@gmail.com', 'createdAt': '2024-08-25T14:18:46.668Z', 'updatedAt': '2024-08-25T14:18:46.668Z', 'trainee_id': 'f96a3bf4-0669-4439-8835-b8bff1ac6ad3', 'Status': 'Accepted'}}, 'meta': {}}
# All records have been inserted successfully

# %%
### new trainees for new batch 
tip.process_for_trainee_submission()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tip.process_for_trainee_submission()
#
# File ~/review/review_scripts/trainee_information_processor.py:291, in TraineeInformationProcesssor.process_for_trainee_submission(self)
#     290 def process_for_trainee_submission(self):
# --> 291     batch = self.get_batch()
#     292     adf = self.select_batch_users_from_allusers()
#     293     adf.rename(columns={"Email":"email"}, inplace=True)
#
# File ~/review/review_scripts/trainee_information_processor.py:285, in TraineeInformationProcesssor.get_batch(self)
#     274 """
#     275     Function to get current batch from strapi graphql
#     276
#    (...)
#     281     Strapi Id of the imputed batch
#     282 """
#     284 batch = int(self.configs.batch)
# --> 285 batch_json = self.cm.read_batch_information(self.sg, {'batch': batch})
#     286 batchdf =  pd.json_normalize(batch_json['data']['batches']['data'])
#     287 batch  = batchdf[batchdf['attributes.Batch']==batch]
#
# File ~/review/review_scripts/communication_manager.py:135, in CommunicationManager.read_batch_information(self, sg, batch_params)
#     120 bquery = """
#     121     query getBatch($batch:Int){
#     122     batches(filters: { Batch:  { eq: $batch } }){
#    (...)
#     132
#     133     """
#     134 # batch = int(self.batch.split("-")[1])
# --> 135 batchJson = sg.Select_from_table(query=bquery, variables={"batch": batch_params['batch']})
#     136 return batchJson
#
# File ~/review/review_scripts/strapi_graphql.py:105, in StrapiGraphql.Select_from_table(self, query, variables)
#     103     return r
#     104 else:
# --> 105     request = requests.post(self.apiroot, json={'query': query, 'variables': variables}, headers=self.headers)
#     106     if request.status_code == 200:
#     107         r =  request.json()
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/requests/api.py:117, in post(url, data, json, **kwargs)
#     105 def post(url, data=None, json=None, **kwargs):
#     106     r"""Sends a POST request.
#     107
#     108     :param url: URL for the new :class:`Request` object.
#    (...)
#     114     :rtype: requests.Response
#     115     """
# --> 117     return request('post', url, data=data, json=json, **kwargs)
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038         if timeout == 0.0:
#    1039             # non-blocking
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#    1043     self.close()
#
# File ~/miniconda3/envs/pjmatch/lib/python3.9/ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1308     if timeout == 0.0 and block:
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#    1312     self.settimeout(timeout)
#
# KeyboardInterrupt:
